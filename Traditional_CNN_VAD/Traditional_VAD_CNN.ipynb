# %%
#@title Import and Install Libraries { vertical-output: true, display-mode: "form" }
from IPython import display

# !pip install keras-layer-normalization
display.clear_output()
print("keras-layer-normalization library is installed successfully")
print()
import matplotlib.pyplot as plt
import numpy as np
import numpy.ma as ma
import tensorflow as tf
import cv2
import os
import keras
import time 
import shutil
import csv
import imageio
import scipy.io

from sklearn.metrics import roc_auc_score
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, ConvLSTM2D, BatchNormalization, TimeDistributed, Activation
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.utils import plot_model
from keras_layer_normalization import LayerNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping
from matplotlib.animation import FuncAnimation, writers
import matplotlib.patches as mpatches
import glob
from os.path import isfile, join, isdir
from PIL import Image
from tqdm import tqdm
from IPython.display import HTML
print("All librairies are imported successfully")
# Out:
# keras-layer-normalization library is installed successfully
#
# All librairies are imported successfully

# %%
# Defining  Paths and Parameters

import os

class Path :

  def __init__(self, choice) :
    root_dir = "path/to/project/"
    expr_dir = root_dir + "Experiments/Video-AD/Trad_VAD_CNN/"
    data_dir = root_dir + "datasets/"

    if (choice == "ped1") :
      self.train = data_dir + "UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train"
      self.test = data_dir + "UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test"
    elif (choice == "ped2"):
      self.train = data_dir + "UCSD_Anomaly_Dataset.v1p2/UCSDped2/Train"
      self.test = data_dir + "UCSD_Anomaly_Dataset.v1p2/UCSDped2/Test"

    self.result = expr_dir + "Results/"+choice
    self.model = expr_dir + "Models/"+choice+"/{}.hdf5"    ## Ex : cla.hdf5
    self.history = expr_dir + "History/"+choice+"/{}_history_log.csv"     ## Ex : cla_history_log.csv
    self.checkpoint = expr_dir + "Checkpoint/"+choice+"/checkpoint-{epoch:02d}-{loss:.4f}.hdf5"      ## Ex : checkpoint-cla-40-001.hdf5
    self.video = expr_dir + "Videos/"+choice       
    self.loss = expr_dir + "Images/"+choice+"/Loss/{}-{}-epochs.png"      ## Ex : cla-50-epochs.png
    self.regularity = expr_dir + "Images/"+choice+"/Regularity/Test{}-{}.png"       ## Ex : Test8-cla.png
    self.auc = expr_dir + "Images/"+choice+"/auc/auc-{}.png"        ## Ex : auc-cla.png
    self.plot = expr_dir + "Images/{}.png"        ## Ex : cla.png
    self.recon_img = expr_dir + "Images/"+choice+"/Reconstructed_images/"

    # Check if directories exist, if not, create them
    if not os.path.exists(self.result):
      os.makedirs(self.result)
    if not os.path.exists(self.video):
      os.makedirs(self.video)
    if not os.path.exists(os.path.dirname(self.history)):
      os.makedirs(os.path.dirname(self.history))
    if not os.path.exists(os.path.dirname(self.checkpoint)):
      os.makedirs(os.path.dirname(self.checkpoint))
    if not os.path.exists(os.path.dirname(self.loss)):
      os.makedirs(os.path.dirname(self.loss))
    if not os.path.exists(os.path.dirname(self.regularity)):
      os.makedirs(os.path.dirname(self.regularity))
    if not os.path.exists(os.path.dirname(self.auc)):
      os.makedirs(os.path.dirname(self.auc))
    if not os.path.exists(os.path.dirname(self.plot)):
      os.makedirs(os.path.dirname(self.plot))
    if not os.path.exists(os.path.dirname(self.recon_img)):
      os.makedirs(os.path.dirname(self.recon_img))

print("Paths and Parameters are defined successfully")
# Out:
# Paths and Parameters are defined successfully

# %% [markdown]
# ### Model creation

# %% [markdown]
# #### CNN-LSTM-AE Model Creation

# %%
def Create_CNN_LSTM_AE():
  model = Sequential(name="CNN-LSTM-AE")
  
  ## Encoding of the data
  model.add(TimeDistributed(Conv2D(256, (11, 11), strides=4, padding="same"), batch_input_shape=(None, 8, 224, 224, 1)))
  model.add(BatchNormalization())
  model.add(Activation("relu"))
  
  model.add(TimeDistributed(Conv2D(128, (5, 5), strides=2, padding="same")))
  model.add(BatchNormalization())
  model.add(Activation("relu"))
  
  model.add(TimeDistributed(Conv2D(64, (3, 3), strides=1, padding="same")))
  model.add(BatchNormalization())
  model.add(Activation("relu"))

  ## Convolution LSTM layer for long-range dependencies
  model.add(ConvLSTM2D(64, (3, 3), padding="same", return_sequences=True))
  model.add(BatchNormalization())
  model.add(Activation("relu"))
  
  model.add(ConvLSTM2D(32, (3, 3), padding="same", return_sequences=True))
  model.add(BatchNormalization())
  model.add(Activation("relu"))

  model.add(ConvLSTM2D(64, (3, 3), padding="same", return_sequences=True))
  model.add(BatchNormalization())
  model.add(Activation("relu"))
  
  ## Decoding of the data
  model.add(TimeDistributed(Conv2DTranspose(64, (3, 3), strides=1, padding="same")))
  model.add(BatchNormalization())
  model.add(Activation("relu"))

  model.add(TimeDistributed(Conv2DTranspose(128, (5, 5), strides=2, padding="same")))
  model.add(BatchNormalization())
  model.add(Activation("relu"))

  model.add(TimeDistributed(Conv2DTranspose(256, (11, 11), strides=4, padding="same")))
  model.add(BatchNormalization())
  model.add(Activation("relu"))
  
  model.add(TimeDistributed(Conv2D(1, (3, 3), activation="tanh", padding="same")))
  return model

print("CNN-LSTM-AE Model has created successfully")
model = Create_CNN_LSTM_AE()
model.summary()
# Out:
# CNN-LSTM-AE Model has created successfully
# Model: "CNN-LSTM-AE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_7 (TimeDis  (None, 8, 56, 56, 256)   31232
#  tributed)
#
#  batch_normalization_9 (Batc  (None, 8, 56, 56, 256)   1024
#  hNormalization)
#
#  activation_9 (Activation)   (None, 8, 56, 56, 256)    0
#
#  time_distributed_8 (TimeDis  (None, 8, 28, 28, 128)   819328
#  tributed)
#
#  batch_normalization_10 (Bat  (None, 8, 28, 28, 128)   512
#  chNormalization)
#
#  activation_10 (Activation)  (None, 8, 28, 28, 128)    0
#
#  time_distributed_9 (TimeDis  (None, 8, 28, 28, 64)    73792
#  tributed)
#
#  batch_normalization_11 (Bat  (None, 8, 28, 28, 64)    256
#  chNormalization)
#
#  activation_11 (Activation)  (None, 8, 28, 28, 64)     0
#
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 8, 28, 28, 64)     295168
#
#  batch_normalization_12 (Bat  (None, 8, 28, 28, 64)    256
#  chNormalization)
#
#  activation_12 (Activation)  (None, 8, 28, 28, 64)     0
#
#  conv_lstm2d_4 (ConvLSTM2D)  (None, 8, 28, 28, 32)     110720
#
#  batch_normalization_13 (Bat  (None, 8, 28, 28, 32)    128
#  chNormalization)
#
#  activation_13 (Activation)  (None, 8, 28, 28, 32)     0
#
#  conv_lstm2d_5 (ConvLSTM2D)  (None, 8, 28, 28, 64)     221440
#
#  batch_normalization_14 (Bat  (None, 8, 28, 28, 64)    256
#  chNormalization)
#
#  activation_14 (Activation)  (None, 8, 28, 28, 64)     0
#
#  time_distributed_10 (TimeDi  (None, 8, 28, 28, 64)    36928
#  stributed)
#
#  batch_normalization_15 (Bat  (None, 8, 28, 28, 64)    256
#  chNormalization)
#
#  activation_15 (Activation)  (None, 8, 28, 28, 64)     0
#
#  time_distributed_11 (TimeDi  (None, 8, 56, 56, 128)   204928
#  stributed)
#
#  batch_normalization_16 (Bat  (None, 8, 56, 56, 128)   512
#  chNormalization)
#
#  activation_16 (Activation)  (None, 8, 56, 56, 128)    0
#
#  time_distributed_12 (TimeDi  (None, 8, 224, 224, 256)  3965184
#  stributed)
#
#  batch_normalization_17 (Bat  (None, 8, 224, 224, 256)  1024
#  chNormalization)
#
#  activation_17 (Activation)  (None, 8, 224, 224, 256)  0
#
#  time_distributed_13 (TimeDi  (None, 8, 224, 224, 1)   2305
#  stributed)
#
# =================================================================
# Total params: 5,765,249
# Trainable params: 5,763,137
# Non-trainable params: 2,112
# _________________________________________________________________

# %% [markdown]
# #### Loss function : Reconstruction loss

# %%
def reconstruction_loss(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))

# %% [markdown]
# ### Train the model

# %%
def training_model(model, model_name, training_set, epochs, option, num_gpus=1):
    cp_callback = ModelCheckpoint(filepath=paths.checkpoint,
                                                     monitor='loss',
                                                     save_weights_only=True,
                                                     verbose=1)
    
    # create the csv logger and file if it does not exist
    if not os.path.exists(paths.history):
        with open(paths.history, mode='w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['epoch', 'train_loss'])
    csv_logger = CSVLogger(paths.history.format(model_name), append=True)
    
    if option == "Load":
        print("# Loading Model ...")
        model = load_model(paths.model.format(model_name), custom_objects={'LayerNormalization': LayerNormalization, 'reconstruction_loss': reconstruction_loss})
        print("# Model Loaded")
        with open(paths.history, newline='') as history:
            data = list(csv.reader(history))
        init_epoch = max([int(data[i][0]) for i in range(1, len(data))]) + 1
    
    elif option == "Create":
        print("# Creating Model ...")
        strategy = tf.distribute.MirroredStrategy(devices=["/gpu:%d" % i for i in range(num_gpus)])
        with strategy.scope():
            model = Create_CNN_LSTM_AE()
            model.compile(loss=reconstruction_loss, optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True))
        init_epoch = 0
        print("# Model Created")

    # early_stop = EarlyStopping(monitor='loss', patience=3, verbose=1)
    start = time.time()
    print("# Training Model ...")
    history = model.fit(training_set, training_set, batch_size=4, epochs=init_epoch+epochs, shuffle=False, callbacks=[cp_callback, csv_logger], initial_epoch=init_epoch)
    print("# Model Trained after %ds" % round(time.time() - start))

    print("# Saving Model ...")
    model.save(paths.model.format(model_name))
    print("# Model Saved to", paths.model.format(model_name))

    return history
# Out:
# # Creating Model ...
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# # Model Created
# # Training Model ...
# Epoch 1/50
# 2023-05-15 01:26:51.134780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_11' with dtype float and shape [310,8,224,224,1]
# 	 [[{{node Placeholder/_11}}]]
# 2023-05-15 01:26:51.135008: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype float and shape [310,8,224,224,1]
# 	 [[{{node Placeholder/_10}}]]
# INFO:tensorflow:batch_all_reduce: 41 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 41 all-reduces with algorithm = nccl, num_packs = 1
# 2023-05-15 01:27:03.455770: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-05-15 01:27:03.593733: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-05-15 01:27:05.457295: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.91GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-15 01:27:06.258207: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_1_bfc) ran out of memory trying to allocate 6.91GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-15 01:27:06.258263: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_1_bfc) ran out of memory trying to allocate 6.91GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-15 01:27:09.500357: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f58434eb510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-15 01:27:09.500380: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2023-05-15 01:27:09.500385: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (1): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-05-15 01:27:09.555825: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 78/78 [==============================] - ETA: 0s - loss: 0.0660
# Epoch 1: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-01-0.0660.hdf5
# 78/78 [==============================] - 53s 436ms/step - loss: 0.0660
# Epoch 2/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 2: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-02-0.0148.hdf5
# 78/78 [==============================] - 33s 418ms/step - loss: 0.0148
# Epoch 3/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0113
# Epoch 3: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-03-0.0113.hdf5
# 78/78 [==============================] - 32s 414ms/step - loss: 0.0113
# Epoch 4/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 4: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-04-0.0089.hdf5
# 78/78 [==============================] - 32s 416ms/step - loss: 0.0089
# Epoch 5/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 5: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-05-0.0078.hdf5
# 78/78 [==============================] - 33s 420ms/step - loss: 0.0078
# Epoch 6/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 6: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-06-0.0076.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0076
# Epoch 7/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 7: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-07-0.0064.hdf5
# 78/78 [==============================] - 33s 420ms/step - loss: 0.0064
# Epoch 8/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 8: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-08-0.0062.hdf5
# 78/78 [==============================] - 33s 420ms/step - loss: 0.0062
# Epoch 9/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0106
# Epoch 9: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-09-0.0106.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0106
# Epoch 10/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 10: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-10-0.0094.hdf5
# 78/78 [==============================] - 33s 420ms/step - loss: 0.0094
# Epoch 11/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 11: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-11-0.0050.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0050
# Epoch 12/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 12: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-12-0.0048.hdf5
# 78/78 [==============================] - 33s 420ms/step - loss: 0.0048
# Epoch 13/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 13: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-13-0.0044.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0044
# Epoch 14/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 14: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-14-0.0060.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0060
# Epoch 15/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 15: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-15-0.0043.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0043
# Epoch 16/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 16: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-16-0.0047.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0047
# Epoch 17/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 17: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-17-0.0039.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0039
# Epoch 18/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0085
# Epoch 18: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-18-0.0085.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0085
# Epoch 19/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 19: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-19-0.0065.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0065
# Epoch 20/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 20: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-20-0.0038.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0038
# Epoch 21/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 21: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-21-0.0039.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0039
# Epoch 22/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 22: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-22-0.0047.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0047
# Epoch 23/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 23: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-23-0.0048.hdf5
# 78/78 [==============================] - 33s 420ms/step - loss: 0.0048
# Epoch 24/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 24: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-24-0.0035.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0035
# Epoch 25/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 25: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-25-0.0036.hdf5
# 78/78 [==============================] - 33s 420ms/step - loss: 0.0036
# Epoch 26/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 26: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-26-0.0035.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0035
# Epoch 27/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 27: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-27-0.0036.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0036
# Epoch 28/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 28: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-28-0.0038.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0038
# Epoch 29/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 29: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-29-0.0041.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0041
# Epoch 30/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 30: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-30-0.0032.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0032
# Epoch 31/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 31: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-31-0.0032.hdf5
# 78/78 [==============================] - 33s 423ms/step - loss: 0.0032
# Epoch 32/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 32: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-32-0.0031.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0031
# Epoch 33/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 33: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-33-0.0029.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0029
# Epoch 34/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 34: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-34-0.0038.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0038
# Epoch 35/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 35: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-35-0.0033.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0033
# Epoch 36/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 36: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-36-0.0028.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0028
# Epoch 37/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 37: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-37-0.0028.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0028
# Epoch 38/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 38: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-38-0.0028.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0028
# Epoch 39/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 39: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-39-0.0028.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0028
# Epoch 40/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 40: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-40-0.0032.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0032
# Epoch 41/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 41: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-41-0.0033.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0033
# Epoch 42/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 42: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-42-0.0031.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0031
# Epoch 43/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 43: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-43-0.0029.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0029
# Epoch 44/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 44: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-44-0.0037.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0037
# Epoch 45/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 45: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-45-0.0031.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0031
# Epoch 46/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 46: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-46-0.0037.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0037
# Epoch 47/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 47: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-47-0.0028.hdf5
# 78/78 [==============================] - 33s 422ms/step - loss: 0.0028
# Epoch 48/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 48: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-48-0.0029.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0029
# Epoch 49/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 49: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-49-0.0025.hdf5
# 78/78 [==============================] - 33s 424ms/step - loss: 0.0025
# Epoch 50/50
# 78/78 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 50: saving model to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Checkpoint/ped2/checkpoint-50-0.0032.hdf5
# 78/78 [==============================] - 33s 421ms/step - loss: 0.0032
# # Model Trained after 1664s
# # Saving Model ...
# # Model Saved to /mnt/db5ee27b-d60f-427d-a8d7-117198a38bb1/Supriyo/Dissertation works/Experiments/Video-AD/SIVAD/Trad_VAD_CNN/Models/ped2/CNN_LSTM_AE.hdf5

# %% [markdown]
# ### For now we will only build the model for UCSD Ped dataset

# %% [markdown]
# #### Free up the GPU memory

# %%
# !pip install numba

# from numba import cuda 
# device = cuda.get_current_device()
# device.reset()

# %% [markdown]
# ### ped1/ped2

# %%
# Choice of Dataset
choice =  "ped2" # param : {"ped1", "ped2""}
paths = Path(choice)

# %% [markdown]
# #### Data preprocessing

# %%
# Creating clips from the frames

def get_clips(frames_list, seq_len):
    '''
    Parametes:
        frames_list : List consists of video frames (image format)
        seq_len : Length of the sequence which indicates how many \
                    sequence of frames would be attached to each clip

    Returns:
        clips : List of clips

    '''
    clips = []
    clip = np.zeros(shape=(seq_len, 224, 224, 1))
    for i, frame in enumerate(frames_list):
            clip[i % seq_len, :, :, 0] = frame
            if (i + 1) % seq_len == 0:
                clips.append(np.copy(clip))

    return clips


def import_data(path):
    clips = []
    for dir_path in sorted(glob.glob(path + "/*/")):
        # print("# Importing " + dir_path)
        all_frames = []
        for img_path in sorted(glob.glob(dir_path + "*.tif")):
            img = Image.open(img_path).resize((224, 224))
            img = np.array(img, dtype=np.float32) / 256.0
            all_frames.append(img)
        clips.extend(get_clips(frames_list=all_frames, seq_len=8))
    print("Importing of the frames has completed")
    return clips

print("Reading frames from video folders...")
training_set = np.array(import_data (paths.train))
print("Trainning Set is imported successfully \n")
print("Trainning Set Shape = ",training_set.shape)
# Out:
# Reading frames from video folders...
# Importing of the frames has completed
# Trainning Set is imported successfully
#
# Trainning Set Shape =  (310, 8, 224, 224, 1)

# %% [markdown]
# #### Training on Ped2 dataset

# %%
model_name = "CNN_LSTM_AE"
option = 'Create' # param : {"Create", "Load"}
number_epochs = 50 # {type:"integer"}
num_gpus = 2 # {type:"integer"}

history = training_model(model, model_name, training_set, number_epochs, option, num_gpus)

# %% [markdown]
# #### Plot the training loss

# %%
# model_name = "CNN_LSTM_AE"
with open(paths.history.format(model_name), newline='') as history:
    data = list(csv.reader(history))
loss = np.array([float(data[i][1]) for i in range (1, len(data))])
epochs = np.array([int(data[i][0]) for i in range (1, len(data))])

plt.figure(figsize=(10, 6))
plt.plot(epochs, loss, '-o', color='blue', linewidth=2, markersize=5, label='loss')
plt.title('CNN-LSTM-AE Training Loss for UCSD ped2', fontsize=18)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(linestyle='--', linewidth=0.5)
plt.legend(loc='best', fontsize=13)
plt.tight_layout()
plt.savefig(paths.loss.format(model_name, max(epochs)+1), dpi=300)
plt.show()

# %% [markdown]
# ### Other task

# %% [markdown]
# #### Visualization of CNN-LSTM-AE model architecture

# %%
# !pip install pydot 
# !sudo apt install graphviz

model = load_model(paths.model.format("CNN_LSTM_AE"),custom_objects={'LayerNormalization': LayerNormalization, 'reconstruction_loss': reconstruction_loss})
plot_model(model, to_file=paths.plot.format("CNN_LSTM_AE"), show_shapes=True, show_layer_names=False, rankdir="TB")

# %%
# !pip install keras_sequential_ascii
from keras_sequential_ascii import keras2ascii
display.clear_output()
keras2ascii(model)
# Out:
#            OPERATION           DATA DIMENSIONS   WEIGHTS(N)   WEIGHTS(%)
#
#                Input   #####      8  224  224    1
#      TimeDistributed   ????? -------------------     31232     0.5%
#                        #####      8   56   56  256
#   BatchNormalization    μ|σ  -------------------      1024     0.0%
#                 relu   #####      8   56   56  256
#      TimeDistributed   ????? -------------------    819328    14.2%
#                        #####      8   28   28  128
#   BatchNormalization    μ|σ  -------------------       512     0.0%
#                 relu   #####      8   28   28  128
#      TimeDistributed   ????? -------------------     73792     1.3%
#                        #####      8   28   28   64
#   BatchNormalization    μ|σ  -------------------       256     0.0%
#                 relu   #####      8   28   28   64
#           ConvLSTM2D   ????? -------------------    295168     5.1%
#                 tanh   #####      8   28   28   64
#   BatchNormalization    μ|σ  -------------------       256     0.0%
#                 relu   #####      8   28   28   64
#           ConvLSTM2D   ????? -------------------    110720     1.9%
#                 tanh   #####      8   28   28   32
#   BatchNormalization    μ|σ  -------------------       128     0.0%
#                 relu   #####      8   28   28   32
#           ConvLSTM2D   ????? -------------------    221440     3.8%
#                 tanh   #####      8   28   28   64
#   BatchNormalization    μ|σ  -------------------       256     0.0%
#                 relu   #####      8   28   28   64
#      TimeDistributed   ????? -------------------     36928     0.6%
#                        #####      8   28   28   64
#   BatchNormalization    μ|σ  -------------------       256     0.0%
#                 relu   #####      8   28   28   64
#      TimeDistributed   ????? -------------------    204928     3.6%
#                        #####      8   56   56  128
#   BatchNormalization    μ|σ  -------------------       512     0.0%
#                 relu   #####      8   56   56  128
#      TimeDistributed   ????? -------------------   3965184    68.8%
#                        #####      8  224  224  256
#   BatchNormalization    μ|σ  -------------------      1024     0.0%
#                 relu   #####      8  224  224  256
#      TimeDistributed   ????? -------------------      2305     0.0%
#                        #####      8  224  224    1

# %% [markdown]
# ### Inference

# %%
def reconstruct_test(model_name, test_num, num_gpus=1):
    model = load_model(paths.model.format(model_name), custom_objects={'LayerNormalization': LayerNormalization, 'reconstruction_loss': reconstruction_loss})
    print("Loaded model")
    
    test_path = os.path.join(paths.test, "Test{}".format(test_num))
    file_list = glob.glob(os.path.join(test_path, "*.tif"))
    num_frames = len(file_list)
    test = np.zeros(shape=(num_frames, 224, 224, 1))
    for i, f in enumerate(sorted(file_list)):
        img = Image.open(f).resize((224, 224))
        img = np.array(img, dtype=np.float32) / 256.0
        test[i, :, :, 0] = img
    print(f"Loaded Test : {test_num}")

    num_frames = test.shape[0] - 8
    print("This video contains {} frames".format(num_frames))
    sequences = [test[i:i+8] for i in range(num_frames)] # use list comprehension with slicing and stride
    sequences = np.array(sequences)
    print(sequences.shape)

    # distribute the model across two GPUs
    # strategy = tf.distribute.MirroredStrategy(devices=["/gpu:%d" % i for i in range(num_gpus)])
    # with strategy.scope():
        # get the reconstruction cost of all the sequences
    reconstructed_sequences = model.predict(sequences, batch_size=4)

    # Create a directory to save the reconstructed images
    output_dir = os.path.join(paths.recon_img, "Test{}".format(test_num))
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Save the reconstructed images
    for i, reconstructed_seq in enumerate(reconstructed_sequences):
        output_path = os.path.join(output_dir, f"reconstructed_image_{i}.png")
        reconstructed_seq = (reconstructed_seq * 256).astype(np.uint8)
        for j, reconstructed_img in enumerate(reconstructed_seq):
            reconstructed_image = Image.fromarray(reconstructed_img[:, :, 0])
            reconstructed_image.save(output_path)

            
    return sequences, reconstructed_sequences

# %% [markdown]
# #### Reconstruct the test images

# %%
# Draw Regularity Graph
model_name = "CNN_LSTM_AE"
# test_num =  8 # param : {type:"integer"}
if choice == 'ped1':
    total_test = 36
else :
    total_test = 12

for test_num in range (1, total_test+1):
    sequences, reconstructed  = reconstruct_test(model_name=model_name, test_num="{0:03}".format(test_num))
# Out:
# Loaded model
# Loaded Test : 018
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:48:14.451606: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5'}.
# 48/48 [==============================] - 9s 177ms/step
# Loaded model
# Loaded Test : 019
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 19s
# 2023-06-08 20:48:29.818805: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5'}.
# 48/48 [==============================] - 9s 178ms/step
# Loaded model
# Loaded Test : 020
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 19s
# 2023-06-08 20:48:45.244449: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5'}.
# 48/48 [==============================] - 9s 179ms/step
# Loaded model
# Loaded Test : 021
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:49:01.160259: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5'}.
# 48/48 [==============================] - 9s 181ms/step
# Loaded model
# Loaded Test : 022
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:49:16.899670: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 023
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 21s
# 2023-06-08 20:49:33.042008: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 024
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 21s
# 2023-06-08 20:49:48.810481: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 025
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:50:04.538763: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3'}.
# 48/48 [==============================] - 9s 179ms/step
# Loaded model
# Loaded Test : 026
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:50:20.650327: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3'}.
# 48/48 [==============================] - 9s 179ms/step
# Loaded model
# Loaded Test : 027
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:50:36.302581: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 028
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:50:51.979142: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 029
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:51:07.861809: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 030
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:51:23.953649: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 031
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:51:39.867725: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 032
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:51:55.513995: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 033
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 40s
# 2023-06-08 20:52:11.695837: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 034
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:52:27.437768: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 035
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:52:43.088087: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3'}.
# 48/48 [==============================] - 9s 180ms/step
# Loaded model
# Loaded Test : 036
# This video contains 192 frames
# (192, 8, 224, 224, 1)
#  1/48 [..............................] - ETA: 20s
# 2023-06-08 20:52:59.024241: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_3/while/body/_1/CNN-LSTM-AE/conv_lstm2d_3/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_4/while/body/_49/CNN-LSTM-AE/conv_lstm2d_4/while/mul_3'}.
# 48/48 [==============================] - 9s 180ms/step

# %% [markdown]
# #### Reconstructed images

# %% [markdown]
# ![recons_cnn_lstm.png](attachment:recons_cnn_lstm.png)

# %% [markdown]
# ### Regularity plot for anomaly detection in frames

# %%
def get_the_gt(test_num):
    import re
    test_num -= 1

    # Read the contents of UCSDped1.m file
    with open(paths.test + '/UCSDped2.m', 'r') as file:
        file_contents = file.read()

    # Define a pattern to match the ground truth frames for the test_num
    pattern = r'TestVideoFile{[^}]+}\.gt_frame\s+=\s+\[(.*?)\];'

    # Find all matches for the pattern in the file_contents
    matches = re.findall(pattern, file_contents)

    # Get the ground truth frames for the specified test_num
    if test_num >= 0 and test_num < len(matches):
        gt_frames = matches[test_num]
    else:
        gt_frames = ""

    # print("Ground truth frames for test_num", test_num, ":", gt_frames)

    return gt_frames

def anomaly_detection(model_name, sequences, reconstructed, threshold, test_num):
    num_frames = sequences.shape[0]
    sequences_reconstruction_cost = np.array([np.linalg.norm(np.subtract(sequences[i],reconstructed[i])) for i in range(0,num_frames)])
    abnormality_score = (sequences_reconstruction_cost - np.min(sequences_reconstruction_cost)) / np.max(sequences_reconstruction_cost)
    regularity_score = 1.0 - abnormality_score
    
    # Identify anomalous frames
    regularity_score = regularity_score.tolist()
    anomaly_frames = []
    for i, score in enumerate(regularity_score):
        if score < threshold:
            anomaly_frames.append(i)

    # plot the regularity scores
    font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 12,
    }

    fig, ax = plt.subplots(figsize=(6,5))
    ax.plot(range(num_frames), regularity_score, 'b')
    for i in anomaly_frames:
        ax.plot(i, regularity_score[i], 'ro')
    ax.axhline(y=threshold, color='r', linestyle='--', label='Threshold')
    # get the ground truth frame label
    gt_frames = get_the_gt(test_num)
    ax.set_xlabel(f'Frame sequence (gt : [{gt_frames}])', fontdict=font)
    ax.set_ylabel('Regularity score (higher the better)', fontdict=font)
    ax.set_title("Regularity scores vs Frame sequence", fontdict=font)
    ax.legend(['Non-anomalous', 'Anomalous'], loc='upper right')
    plt.savefig(paths.regularity.format(test_num, model_name))
    plt.show()
    display.clear_output()
    
    
    return regularity_score, anomaly_frames

# Draw Regularity Graph
model_name = "CNN_LSTM_AE"
# test_num =  8 # param : {type:"integer"}
if choice == 'ped1':
    threshold = 0.9
    total_test = 36
else :
    threshold = 0.96
    total_test = 12


for test_num in range (1, total_test+1):
    sequences, reconstructed  = reconstruct_test(model_name=model_name, test_num="{0:03}".format(test_num))
    regularity_score, anomaly_frames = anomaly_detection(model_name, sequences, reconstructed, threshold, test_num)

# %% [markdown]
# ### Animation of regularity score in a test video

# %% [markdown]
# #### Creating a video from the frames of it.

# %%
def frames_to_video(image_input_path, video_output_path, img_format, fps=30):
    # Set the paths
    if not os.path.exists(os.path.dirname(video_output_path)):
        os.makedirs(os.path.dirname(video_output_path))

    # Get the list of images
    images = sorted(glob.glob(os.path.join(image_input_path, '*.{}'.format(img_format))))
    if not images:
        raise ValueError('No images found in {}'.format(image_input_path))

    # Read the first image to get the dimensions
    frame = cv2.imread(images[0])
    if frame is None:
        raise ValueError('Failed to read image: {}'.format(images[0]))
    height, width, layers = frame.shape

    # Create the video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video = cv2.VideoWriter(video_output_path, fourcc, fps, (width, height))
    if not video.isOpened():
        raise ValueError('Failed to open video writer')

    # Write the frames to the video
    for image in images:
        frame = cv2.imread(image)
        if frame is None:
            raise ValueError('Failed to read image: {}'.format(image))
        video.write(frame)

    # Release the video writer and destroy all windows
    video.release()
    cv2.destroyAllWindows()

# %%
# test_nums = [2, 3, 5, 10, 13, 30, 32, 33] # ped1
test_nums = [2, 3, 4, 6, 7, 10, 11] # ped2
for test_num in test_nums:
    frame_folder = paths.test + '/Test{0:03}'.format(test_num)
    video_output_path = paths.video + '/Test{0:03}/video.mp4'.format(test_num)

    frames_to_video(frame_folder, video_output_path, img_format='tif', fps=20)

# %% [markdown]
# #### Animation

# %%
# test_nums = [2, 3, 5, 10, 13, 30, 32, 33] # ped1
test_nums = [2, 3, 4, 6, 7, 10, 11] # ped2
for test_num in test_nums:
    sequences, reconstructed  = reconstruct_test(model_name=model_name, test_num="{0:03}".format(test_num))
    regularity_score, anomaly_frames = anomaly_detection(model_name, sequences, reconstructed, threshold, test_num)

    # Define the paths
    video_path = paths.video + '/Test{0:03}/video.mp4'.format(test_num)
    # regularity_score_path = "path/to/regularity_score.npy"
    output_path = paths.video + '/Test{0:03}/animated_Graph.mp4'.format(test_num)

    # Load the video
    cap = cv2.VideoCapture(video_path)

    # Load the regularity score
    regularity_score = np.array(regularity_score)

    # Define the figure and axes for the plot and the video
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    line, = ax1.plot([], [])
    ax1.axhline(y=threshold, color='r', linestyle='--', label='Threshold')
    ax1.grid(True)
    # get the ground truth frame label
    gt_frames = get_the_gt(test_num)
    ax1.set_xlabel(f'Frame sequence (gt : [{gt_frames}])')
    ax1.set_ylabel('Regularity score (higher the better)')
    ax1.set_title("Regularity scores vs Frame sequence")
    ax1.legend(loc='upper right')

    img = ax2.imshow(cap.read()[1], cmap="gray")

    # Define the initialization function for the animation
    def init():
        ax1.set_xlim(0, regularity_score.shape[0])
        return line,

    # Define the update function for the animation
    def update(frame):
        _, frame_img = cap.read()
        line.set_data(range(frame+1), regularity_score[:frame+1])
        if frame == regularity_score.shape[0] - 1:
            cap.release()
        else:
            img.set_data(frame_img)
        return line, img

    # Create the animation
    ani = FuncAnimation(fig, update, frames=regularity_score.shape[0],
                                interval=20, blit=True, init_func=init)

    # Save the animation
    Writer = writers['ffmpeg']
    writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1600)
    ani.save(output_path, writer=writer)

# %% [markdown]
# ### AUC ROC curve

# %%
# paths = Path(choice='ped1')
# threshold = 0.96
y_true_all = []
y_pred_all = []
root_dir = "path/to/project/"
if choice == 'ped1' :
    history_dir = 'History/ped1'
    total_test = 36
    auc_list = [0]*total_test
else :
    history_dir = 'History/ped2'
    total_test = 12
    auc_list = [0]*total_test

strategy = tf.distribute.MirroredStrategy(devices=["/gpu:%d" % i for i in range(2)])
with strategy.scope():
    for num in range(1, total_test+1):
        gt_folder = paths.test + '/Test{0:03}_gt'.format(num)
        if not os.path.exists(gt_folder):
            # skip this test case if the "gt" folder does not exist
            continue
        
        # reconstruct the video frames for this test case
        sequences, reconstructed = reconstruct_test(model_name=model_name, test_num="{0:03}".format(num))
        error = sequences - reconstructed
        sz = sequences.shape[0]
        nb_frames = sz + 8
        ground_truth = [0]*nb_frames
        
        # read the ground truth for this test case
        for i in range(nb_frames):
            try:
                im = imageio.imread(gt_folder + '/{0:03}.bmp'.format(i+1))
            except (FileNotFoundError, IndexError):
                continue
            if im.max() == 255:
                ground_truth[i-1] = 1
        
        sequences_reconstruction_cost = np.array([np.linalg.norm(np.subtract(sequences[i], reconstructed[i])) for i in range(0, nb_frames-8)])
        sa = (sequences_reconstruction_cost - np.min(sequences_reconstruction_cost)) / np.max(sequences_reconstruction_cost)
        sr = 1.0 - sa
        y_pred = [0]*sz
        for i in range(sz):
            if sr[i] < threshold:
                y_pred[i] = 1
        y_true = ground_truth[:-8]
        try:
            auc_score = roc_auc_score(y_true, y_pred)
        except ValueError:
            auc_score = 0
            
        display.clear_output()
        print("AUC of video (No :", num, ") = ", auc_score)
        auc_list[num-1] = auc_score
        y_true_all.extend(y_true)
        y_pred_all.extend(y_pred)
        data = [num, auc_score]
        with open(history_dir + f'/AUC_{model_name}.csv', 'a') as f:
            writer = csv.writer(f)
            writer.writerow(data)


lst = [x for x in auc_list if x > 0]
print("The mean of AUC: ", sum(lst) / len(lst))
# Out:
# AUC of video (No : 12 ) =  0
# The mean of AUC:  0.7853204780087744

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# calculate the false positive rate (fpr) and true positive rate (tpr)
fpr, tpr, thresholds = roc_curve(y_true_all, y_pred_all)
roc_auc = auc(fpr, tpr)

# plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='red', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random guess')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC AUC curve)')
plt.legend(loc="lower right")
plt.savefig(paths.auc.format(model_name))
plt.show()

# %% [markdown]
# ### Localization of the anomaly in the video

# %%
def compute_sum_of_squares(num: int, error: np.ndarray) -> np.ndarray:
    """
    Compute the sum of squares of the pixel values within a window of size (num, num) for each pixel in the frames
    of the input 'error' array : error = sequences-reconstructed_seq.

    Parameters:
    num (int): The size of the window.
    error (np.ndarray): The input array of frames.

    Returns:
    np.ndarray: An array containing the sum of squares for each pixel position in each frame.
    """

    num_frames, size_img = error.shape[0], error.shape[2]

    # Initialize the output array
    filtered_frames = np.zeros((num_frames, size_img - num, size_img - num))

    # Loop over each frame
    for t in range(num_frames):
        img = error[t][0]
        img = np.asarray(img.reshape(224, 224))

        # Compute the sum of squares for each pixel position in the current frame
        for i in range(size_img-num):
            for j in range(size_img-num):
                filtered_frames[t][i][j] = np.square(img[i:i+num, j:j+num]).sum()

    # Loop over the last 8 frames
    for t in range(1, 9):
        img = error[-1][-t]
        img = np.asarray(img.reshape(224, 224))

        # Compute the sum of squares for each pixel position in the current frame
        for i in range(size_img-num):
            for j in range(size_img-num):
                filtered_frames[num_frames - 9 + t][i][j] = np.square(img[i:i+num, j:j+num]).sum()

    # print(filtered_frames.shape)
    return filtered_frames

# %%
# ff = compute_sum_of_squares(16, error)
# ff

# %%
## This function that draw rectangles in anomaly position

def localize_anomalies(num, img, fil):
    result_path = paths.result+"/Test{0:03}/".format(num)
    input_frame_path = paths.test+'/Test{0:03}/{1}.tif'.format(num, img)
    output_frame_path = result_path + img + ".jpg"
    if not os.path.exists(os.path.dirname(output_frame_path)):
      os.makedirs(os.path.dirname(output_frame_path))
      
    img = cv2.imread(input_frame_path)
    image = cv2.resize(img,(224, 224))
    I=[]
    J=[]
    # Find coordinates of anomalies in filter array
    for i in range(208):
      for j in range(208):
        if (fil[j][i]) :
          I.append(i)
          J.append(j)

    # Overlay rectangles on image for each anomaly
    overlay = image.copy()
    for i in range (len(I)):
      start_point = (I[i], J[i])
      end_point = (I[i]+16, J[i]+16)
      # First we crop the sub-rect from the image
      cv2.rectangle(overlay, start_point, end_point, (0, 0, 200), -1)  # A filled rectangle

    # Apply transparency to overlay and save output image
    alpha = 0.4  # Transparency factor.
    localize_frames = cv2.addWeighted(overlay, alpha, image, 1 - alpha, 0)
    cv2.imwrite(output_frame_path, localize_frames)

# %%
test_num = 3
sequences, reconstructed  = reconstruct_test(model_name=model_name, test_num="{0:03}".format(test_num))
error = sequences-reconstructed
num_frames = sequences.shape[0]
sequences_reconstruction_cost = np.array([np.linalg.norm(np.subtract(sequences[i],reconstructed[i])) for i in range(0,num_frames)])
abnormality_score = (sequences_reconstruction_cost - np.min(sequences_reconstruction_cost)) / np.max(sequences_reconstruction_cost)
regularity_score = 1.0 - abnormality_score

# Compute the anomaly positions
fil = compute_sum_of_squares(16, error)
# fil

# %%
np.max(fil)
# Out:
# 15.536971227656789

# %% [markdown]
# #### Find the anomalies pixel-wise

# %%
# Anomaly Localization
# test_nums = [2, 3, 5, 10, 13, 30, 32, 33] # ped1
test_nums = [2, 3, 4, 6, 7, 10, 11] # ped2
for test_num in test_nums:
    # Select spatial threshold after which it will be detected as anomaly
    # s_threshold = 4 # ped1 param : {type:"slider", min:0, max:20, step:0.5}
    s_threshold = 6 # ped2 param : {type:"slider", min:0, max:20, step:0.5}
    # s_threshold = 25 # ped2 4 param : {type:"slider", min:0, max:20, step:0.5}
    path = paths.result+"/Test{0:03}/".format(test_num)

    sequences, reconstructed  = reconstruct_test(model_name=model_name, test_num="{0:03}".format(test_num))
    error = sequences-reconstructed
    num_frames = sequences.shape[0]
    sequences_reconstruction_cost = np.array([np.linalg.norm(np.subtract(sequences[i],reconstructed[i])) for i in range(0,num_frames)])
    abnormality_score = (sequences_reconstruction_cost - np.min(sequences_reconstruction_cost)) / np.max(sequences_reconstruction_cost)
    regularity_score = 1.0 - abnormality_score

    # Compute the anomaly positions
    fil = compute_sum_of_squares(16, error)
    anomaly_positions = fil > s_threshold
    for f in sorted(os.listdir(paths.test+"/Test{0:03}/".format(test_num))):
      if f[-3:] == "tif":
        if (int(f[0:3]) < num_frames-8) and (regularity_score[int(f[0:3])-1] < threshold):
          localize_anomalies(test_num, f[0:3], anomaly_positions[int(f[0:3])-1])
        else : 
          path = paths.result+"/Test{0:03}/".format(test_num)
          # print(path)
          img_path = path + f[0:3] + ".jpg"
          path = paths.test+'/Test{0:03}/{1}.tif'.format(test_num, f[0:3])
          img = cv2.imread(path)
          image = cv2.resize(img,(224, 224))
          cv2.imwrite(img_path, image)
    print("Anomaly localization is done successfully")
# Out:
# Loaded model
# Loaded Test : 002
# This video contains 172 frames
# (172, 8, 224, 224, 1)
#  1/43 [..............................] - ETA: 18s
# 2023-05-16 02:19:28.972281: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/Tanh_1' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/convolution_7' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/add_6', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_3'}.
# 43/43 [==============================] - 8s 181ms/step
# Anomaly localization is done successfully
# Loaded model
# Loaded Test : 003
# This video contains 142 frames
# (142, 8, 224, 224, 1)
# 36/36 [==============================] - 7s 199ms/step
# Anomaly localization is done successfully
# Loaded model
# Loaded Test : 004
# This video contains 172 frames
# (172, 8, 224, 224, 1)
#  1/43 [..............................] - ETA: 19s
# 2023-05-16 02:20:27.080467: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/Tanh_1' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/mul_5', 'Func/CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/input/_164' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/mul_2', 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/convolution_7' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/add_6', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_5'}.
# 43/43 [==============================] - 8s 184ms/step
# Anomaly localization is done successfully
# Loaded model
# Loaded Test : 006
# This video contains 172 frames
# (172, 8, 224, 224, 1)
#  1/43 [..............................] - ETA: 18s
# 2023-05-16 02:21:00.380166: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/convolution_7' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/add_6', 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/Tanh_1' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/add_4'}.
# 43/43 [==============================] - 8s 181ms/step
# Anomaly localization is done successfully
# Loaded model
# Loaded Test : 007
# This video contains 172 frames
# (172, 8, 224, 224, 1)
#  1/43 [..............................] - ETA: 17s
# 2023-05-16 02:21:32.000191: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'Func/CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/input/_164' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/mul_2', 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/Tanh_1' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/convolution_7' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/add_6', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_3', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_5'}.
# 43/43 [==============================] - 8s 181ms/step
# Anomaly localization is done successfully
# Loaded model
# Loaded Test : 010
# This video contains 142 frames
# (142, 8, 224, 224, 1)
# 36/36 [==============================] - 8s 202ms/step
# Anomaly localization is done successfully
# Loaded model
# Loaded Test : 011
# This video contains 172 frames
# (172, 8, 224, 224, 1)
#  1/43 [..............................] - ETA: 19s
# 2023-05-16 02:22:31.925076: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/Tanh_1' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/convolution_7' -> 'CNN-LSTM-AE/conv_lstm2d_9/while/body/_1/CNN-LSTM-AE/conv_lstm2d_9/while/add_6', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_2' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/add_5', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/clip_by_value_2' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_5', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/convolution_6' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/add_4', 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/clip_by_value' -> 'CNN-LSTM-AE/conv_lstm2d_10/while/body/_49/CNN-LSTM-AE/conv_lstm2d_10/while/mul_3'}.
# 43/43 [==============================] - 8s 183ms/step
# Anomaly localization is done successfully

# %% [markdown]
# #### Create localized anomaly videos

# %%
# test_nums = [2, 3, 5, 10, 13, 30, 32, 33] # ped1
test_nums = [2, 3, 4, 6, 7, 10, 11] # ped2
for test_num in test_nums:
    output_localize_video = paths.video+'/Test{0:03}/Localize.mp4'.format(test_num)
    localize_frames = paths.result+"/Test{0:03}/".format(test_num)
    frames_to_video(localize_frames, output_localize_video, img_format='jpg', fps=20)
